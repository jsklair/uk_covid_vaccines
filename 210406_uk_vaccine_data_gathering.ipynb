# %%
import pandas as pd

data = pd.read_excel(r'C:\Users\Jazz\Documents\vaccine_data\COVID-19-weekly-announced-vaccinations-1-April-2021.xlsx', sheet_name='MSOA', header = 11, nrows=6794,  usecols = 'B:O')

# %%
print(data)
# Out:
#      Region Code (Administrative) Region Name (administrative)  LTLA Code  \
# 0                             NaN                          NaN        NaN
# 1                           Total                          NaN      Total
# 2                             NaN                          NaN        NaN
# 3                       E12000004                East Midlands  E06000015
# 4                       E12000004                East Midlands  E06000015
# ...                           ...                          ...        ...
# 6789                    E12000003     Yorkshire and the Humber  E08000036
# 6790                    E12000003     Yorkshire and the Humber  E08000036
# 6791                    E12000003     Yorkshire and the Humber  E08000036
# 6792                    E12000003     Yorkshire and the Humber  E08000036
# 6793                    E12000003     Yorkshire and the Humber  E08000036
#
#       LTLA Name  MSOA Code        MSOA Name  \
# ...

# %%
data.to_csv(r'C:\Users\Jazz\Documents\vaccine_data\COVID-19-weekly-announced-vaccinations-1-April-2021.csv', index = False)
